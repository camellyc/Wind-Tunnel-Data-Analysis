# %%
pip install pyperclip
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11102 sha256=8d53796b40a888d1189d484277448cd789769dc516ffe3332be3ac53d560e207
#   Stored in directory: /Users/camellyc/Library/Caches/pip/wheels/9c/79/90/c9e831caaffa2633ad99f1d35c6ea39866b92de62e909e89ef
# Successfully built pyperclip
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nbformat
import pyperclip

# Load the notebook
with open('/Users/camellyc/Library/CloudStorage/GoogleDrive-yichen@tuthill.casa/.shortcut-targets-by-id/10pxdlRXtzFB-abwDGi0jOGOFFNm3pmFK/Tuthill Lab Shared/Yichen/Spiracle/Wind_Tunnel_Data/analysis/optotrigger_diagnostic_plots.ipynb', 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Extract only code cells
code_cells = [cell['source'] for cell in nb.cells if cell['cell_type'] == 'code']

# Join all code cells with newlines between them
all_code = '\n\n'.join(code_cells)

# Copy to clipboard
pyperclip.copy(all_code)
print("All code copied to clipboard!")
# Out:
# All code copied to clipboard!
